# %% [markdown]
# <a href="https://colab.research.google.com/github/seobojung/ABCD-A/blob/20250516/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EA%B8%B0%EC%B4%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 'I love python'
print( len(a) )

b = 'abcd'
print( len(b) )
# Out:
# 13
# 4

# %%
name = 'BlackDMask'
phone = '010 xxxx xxxx'
address = 'korea'
print( len(name) )
print( len(phone) )
print( len(address) )
# Out:
# 10
# 13
# 5

# %%
a = [1, 2, 3]
print( max(a) )

b = 'bBlackDMask'
print( max(b) )

c = 1
#print( max(c) )

d = [6, 5, 4, 2]
print( max(d) )

e = [3, 4, 5, 'a', 'b', 'c']
#print( max(e) )

a = [1, 2, 3]
b = [4, 5, 6]
print( max(a, b) )

c = 'BBB'
d = 'BB'
print( min(c, d) )
# Out:
# 3
# s
# 6
# [4, 5, 6]
# BB

# %%
myString = 'everdevel'
print(myString.count('ev'))

a = 'BlockDMask'
print('#1 a.count("k")')
print(a.count("k"))
print('#2 a.count("DM")')
print(a.count("DM"))
print("#3 a[2] + ' ~ ' + a[4]")
print(a[2] + ' ~ ' + a[4])
print("#4 a.count('k', 2, 3)")
print(a.count('k', 2, 3))
print("#5 a.count('k', 2, 4)")
print(a.count('k', 2, 4))
print("#6 a.count('k', 2, 5)")
print(a.count('k', 2, 5))
# Out:
# 2
# #1 a.count("k")
# 2
# #2 a.count("DM")
# 1
# #3 a[2] + ' ~ ' + a[4]
# o ~ k
# #4 a.count('k', 2, 3)
# 0
# #5 a.count('k', 2, 4)
# 0
# #6 a.count('k', 2, 5)
# 1

# %%
#str = "BlockDMask Blog.";
#print(f"str : {str}\n")

#result1 = str.find('a')
#result2 = str.find('z')
#print(f"str.find('a') : {result1}")
#print(f"str.find('z') : {result2}")
#result3 = str.find('ask')
#print(f"str.find('ask') : {result3}")
#result4 = str.find('kkk')
#print(f"str.find('kkk') : {result4}")
#print()
print("2. str.find('찾을 문자, 시작 index')")
result5 = str.find('o')
result6 = str.find('o', 5)
print(f"str.find('o') : {result5}")
print(f"str[5]' : {str[5]}")
print(f"str.find('o', 5) : {result6}")
print()
# Out:
# 2. str.find('찾을 문자, 시작 index')
# str.find('o') : 2
# str[5]' : D
# str.find('o', 5) : 13

# %%
str = ".BlockDMascleark Blog.";
print(f"str : {str}\n")

result1 = str.rfind('.', 0, 5)
result2 = str.find('z')
print(f"str.rfind('.', 0, 5) : {result1}")
print(f"str.find('z') : {result2}")
result3 = str.find('ask')
print(f"str.find('ask') : {result3}")
result4 = str.find('kkk')
print(f"str.find('kkk') : {result4}")
print()
print("2. str.find('찾을 문자, 시작 index')")
result5 = str.find('o')
result6 = str.find('o', 5)
print(f"str.find('o') : {result5}")
print(f"str[5]' : {str[5]}")
print(f"str.find('o', 5) : {result6}")
print()
# Out:
# str : .BlockDMascleark Blog.
#
# str.rfind('.', 0, 5) : 0
# str.find('z') : -1
# str.find('ask') : -1
# str.find('kkk') : -1
#
# 2. str.find('찾을 문자, 시작 index')
# str.find('o') : 3
# str[5]' : k
# str.find('o', 5) : 19

# %%
str = 'Hello world, python!'
if str.startswith('Hello'):
  print('it start with Hello')
if not str.startswith('python'):
  print('it does not start with python')
print(str.startswith('Hello'))
print(str.startswith('python'))
# Out:
# it start with Hello
# it does not start with python
# True
# False
